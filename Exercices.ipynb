# %%
# Hello + indentité

print("Hi guys my name is Sylvain FAYE !")

# %%
#Chiffre d'affaire

print(12*19.9,"est le chiffre d'affaire de l'entreprise!")

# %%
#Afficher texte plus nombre total
total=250

print(f"Voici le nombre total de la somme :{total}")
print("Voici le nombre total de la somme: ",total)

# %%
#Marge
marge =12.5

print(f"La marge est de {marge} % avec marge =",marge)

# %%
#Pourcentage

prix= 80
pourcentage = (92-prix)/92*100
pourcentage
# Out:
# 13.043478260869565

# %%
#Liste

ventes=[100,90,120,150]
total_ventes= sum(ventes)
longeur= len(ventes)

total_ventes
# Out:
# 460

# %%
longeur
# Out:
# 4

# %%
liste=[10,20,30]
liste.append(40)
liste
liste.remove(liste[0])
liste
# Out:
# [20, 30, 40]
